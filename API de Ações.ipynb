# %% [markdown]
# ### Alpha Vantage
#
# https://www.alphavantage.co/documentation/

# %% [markdown]
# #### Pegando cotações semanais - JSON

# %%
import requests
chave_api ='ROK04RYWBLCBQR6G'

import requests

# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = f'https://www.alphavantage.co/query?function=TIME_SERIES_WEEKLY_ADJUSTED&symbol=IBM&apikey={chave_api}'
r = requests.get(url)
data = r.json()

print(data['Meta Data'])
# Out:
# {'1. Information': 'Weekly Adjusted Prices and Volumes', '2. Symbol': 'IBM', '3. Last Refreshed': '2026-05-11', '4. Time Zone': 'US/Eastern'}

# %% [markdown]
# #### Pegando cotações semanais - CSV

# %%
import pandas as pd
from io import StringIO
# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = f'https://www.alphavantage.co/query?function=TIME_SERIES_WEEKLY_ADJUSTED&symbol=IBM&apikey={chave_api}&datatype=csv'
r = requests.get(url)
tabela = pd.read_csv(StringIO(r.text))

display(tabela)
# Out:
#        timestamp    open    high     low   close  adjusted close    volume  \
# 0     2026-05-11  228.66  230.23  222.55  223.55        223.5500   6677186
# 1     2026-05-08  232.00  234.09  224.38  229.76        229.7600  26716501
# 2     2026-05-01  229.95  235.95  224.90  232.20        230.5045  29532709
# 3     2026-04-24  255.00  258.50  221.73  231.98        230.2861  55047502
# 4     2026-04-17  233.63  255.65  231.70  253.47        251.6192  23495380
# ...          ...     ...     ...     ...     ...             ...       ...
# 1379  1999-12-10  113.00  122.12  107.56  109.00         53.1750  58626000
# 1380  1999-12-03  104.94  112.87  102.12  111.87         54.5751  37670000
# 1381  1999-11-26  105.50  109.87  101.81  105.00         51.2236  37165600
# 1382  1999-11-19   96.00  105.12   92.62  103.94         50.7065  61550800
# 1383  1999-11-12   90.50   97.50   90.50   95.87         46.7696  43569700
#
#       dividend amount
# 0                0.00
# 1                1.69
# 2                0.00
# 3                0.00
# 4                0.00
# ...               ...
# 1379             0.00
# 1380             0.00
# 1381             0.00
# 1382             0.00
# 1383             0.12
#
# [1384 rows x 8 columns]

# %% [markdown]
# ### Cotações

# %%
# PEgando várias cotações de uma vez
acoes = ['ITUB4', 'ABEV3', 'BBAS3']

compilada = pd.DataFrame()

for acao in acoes:
    # Cotações do Itaú
    url = f'https://www.alphavantage.co/query?function=GLOBAL_QUOTE&symbol={acao}.SAO&apikey={chave_api}&datatype=csv'
    r = requests.get(url)
    tabela = pd.read_csv(StringIO(r.text))
    lista_tabelas = [compilada, tabela]
    compilada = pd.concat(lista_tabelas)

display(compilada)

# %% [markdown]
# ### Encontrar ativos

# %%
# Encontrando os ativos pelo nome da empresa
url = f'https://www.alphavantage.co/query?function=SYMBOL_SEARCH&keywords=itau&apikey={chave_api}&datatype=csv'
r = requests.get(url)
tabela = pd.read_csv(StringIO(r.text))

display(tabela)
# Out:
#        symbol                                               name         type  \
# 0        ITUB                         Itau Unibanco Holding S.A.       Equity
# 1  ISTT11.SAO  Itau Isento Setembro 29 Fundo De Investimento ...  Mutual Fund
# 2  ITRI11.SAO  Itau Total Return Fundo De Investimento Imobil...  Mutual Fund
# 3  IFRA11.SAO  Itau FIC De Fundos De Investimento Em Direitos...          ETF
# 4  IFRI11.SAO  Itau Fundo De Investimento Em Cotas De FIDIFEI...  Mutual Fund
# 5  TMPS11.SAO      Itau Tempus Fundo De Investimento Imobiliario       Equity
# 6  RURA11.SAO              Itau Asset Rural Fiagro - Imobiliario          ETF
#
#              region marketOpen marketClose timezone currency  matchScore
# 0     United States      09:30       16:00   UTC-04      USD      0.7500
# 1  Brazil/Sao Paolo      10:00       17:30   UTC-03      BRL      0.4615
# 2  Brazil/Sao Paolo      10:00       17:30   UTC-03      BRL      0.4615
# 3  Brazil/Sao Paolo      10:00       17:30   UTC-03      BRL      0.3077
# 4  Brazil/Sao Paolo      10:00       17:30   UTC-03      BRL      0.3077
# 5  Brazil/Sao Paolo      10:00       17:30   UTC-03      BRL      0.3077
# 6  Brazil/Sao Paolo      10:00       17:30   UTC-03      BRL      0.1951

# %% [markdown]
# ### Informações de Resultado

# %%
# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = f'https://www.alphavantage.co/query?function=SHARES_OUTSTANDING&symbol=AMZN&apikey={chave_api}'
r = requests.get(url)
data = r.json()

print(data)
# Out:
# {'symbol': 'AMZN', 'status': 'success', 'data': [{'date': '2026-03-31', 'shares_outstanding_diluted': '10874000000', 'shares_outstanding_basic': '10874000000'}, {'date': '2025-12-31', 'shares_outstanding_diluted': '10863000000', 'shares_outstanding_basic': '10863000000'}, {'date': '2025-09-30', 'shares_outstanding_diluted': '10845000000', 'shares_outstanding_basic': '10845000000'}, {'date': '2025-06-30', 'shares_outstanding_diluted': '10806000000', 'shares_outstanding_basic': '10806000000'}, {'date': '2025-03-31', 'shares_outstanding_diluted': '10793000000', 'shares_outstanding_basic': '10603000000'}, {'date': '2024-12-31', 'shares_outstanding_diluted': '10769000000', 'shares_outstanding_basic': '10551000000'}, {'date': '2024-09-30', 'shares_outstanding_diluted': '10735000000', 'shares_outstanding_basic': '10501000000'}, {'date': '2024-06-30', 'shares_outstanding_diluted': '10708000000', 'shares_outstanding_basic': '10447000000'}, {'date': '2024-03-31', 'shares_outstanding_diluted': '10670000000', 'shares_outstanding_basic': '10393000000'}, {'date': '2023-12-31', 'shares_outstanding_diluted': '10612000000', 'shares_outstanding_basic': '10358000000'}, {'date': '2023-09-30', 'shares_outstanding_diluted': '10558000000', 'shares_outstanding_basic':